# %%
import pandas as pd

import random
import re
import pickle
import nltk

# %%
dataset = pd.read_csv("reviews.csv",sep="\t")
dataset.drop(columns= "Unnamed: 0",inplace = True)
dataset
# Out:
# /home/anubhav/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 0              US     20422322   R8MEA6IGAHO0B  B00MC4CED8       217304173
# 1              US     40835037  R31LOQ8JGLPRLK  B00OQMFG1Q       137313254
# 2              US     51469641  R2Y0MM9YE6OP3P  B00QERR5CY        82850235
# 3              US      4332923   RRB9C05HDOD4O  B00QUFTPV4       221169481
# 4              US     44855305  R26I2RI1GFV8QG  B0067XVNTG       563475445
# 5              US      7846966   RY8DDL22YG4R5  B00KA6CCVY       713636156
# 6              US     21299354  R2AT2426ZHFUHH  B00MJCDPM2       754171872
# 7              US     28902968  R3RRXU2R23NMQ9  B00ET5AWBY       508373185
# 8              US      2074438  R250PR8VJUZ62F  B00Z9K379C       759387370
# 9              US     48701722   RBEMQ29WJBHYG  B00YO3UYXW       913911909
# 10             US      2990247  R19VVIUT4BZCMT  B011W26BU2       938399424
# 11             US     52946117  R1DT8JJUQHUKUL  B00H8PI78C       661515294
# 12             US     49359994   RLIL6S9OGM3YA  B00M49C6MK        91176851
# 13             US      4158732  R34EZZ68VYPHO0  B011Q291PK       891142775
# 14             US     18944032  R3TZNSOXS13SIG  B00W6OLUGQ       577462547
# 15             US       279606  R12UBZT87UX3AP  B008MY1F8W       680240984
# 16             US     10947966   R5KCRE927NYMU  B00KW3XNUE       219920841
# 17             US     18387442   RT12RQFU0V2AX  B009NGR0AK       254898339
# 18             US     48950322  R2K0YQPV5W2SJ1  B011W26BU2       938399424
# 19             US     48148197  R104MY31OKNGXH  B00PAP68WO       366592530
# 20             US       133451  R3EQYRGIIJQBHT  B0105XU088       673736961
# 21             US     24863069  R32MW6D6CXKCFW  B00LTCIT7Y       332806411
# 22             US      6202237   RFO6FJSAA391Z  B00KGPB9ZY       345680591
# 23             US     23652105  R1IG9KI4EWNE4W  B00PHZS078       531752206
# 24             US       399812  R3IF1H9L7WSGQD  B00XWY8MO2       124821171
# 25             US     48805811  R38T4K7X8UBVO7  B00HR0ZTD4       772901687
# 26             US       528818  R19C76D4LWB6CM  B00MXET7NC       651107618
# 27             US     10757416  R260G1C72KG6KC  B00LHXWPI4       952189067
# 28             US     30841819  R2SLX39DAJSG0V  B00TQYCU0Y       328706129
# 29             US     32397073   R5I2YBT9J85FF  B011W26BU2       938399424
# ...           ...          ...             ...         ...             ...
# 88540          US     36802928   RR5LBI7TDSXD0  B00005OTZQ       554527960
# 88541          US     40777856   RVEPY5I8VVDM0  B00006I5T0        54788647
# 88542          US     40655152  R2PV7LO17XOA10  B00006I56D       189704290
# 88543          US     33731940  R1541L5Z2QZBRO  B00005OTZQ       554527960
# 88544          US     48720801   RO6C8A1DXH8NW  B00005OTZQ       554527960
# 88545          US     34363777  R30YJU1OITJNXQ  B00006I5T1       369538915
# 88546          US     34214603   R5UUPIKJ35CO7  B00006I5T0        54788647
# 88547          US     34914255  R1T2SQ4LKQMLHW  B00005OTZQ       554527960
# 88548          US     49071214  R2FRFX3W6G5A4Z  B00005OTZQ       554527960
# 88549          US     46085817   RDQXB47LBMSWB  B00005OTZQ       554527960
# 88550          US     52388312  R2MB9EN5PMYLM8  B00005OTZQ       554527960
# 88551          US     51340837   RT2KU4T6FBR4A  B00005OTZQ       554527960
# 88552          US     37503336  R1FUU42TS1UQNG  B00005OTZQ       554527960
# 88553          US     51895028   RW4DAC97PHLBS  B00006I5UX       966530372
# 88554          US     49144295  R3EL3NJR3SGQKA  B00005OTZQ       554527960
# 88555          US     40309631  R1PXJWI37WA4S8  B00005OTZQ       554527960
# 88556          US     40309631  R2Y12ZPW6OMTCR  B00005OTZQ       554527960
# 88557          US     34643434  R33ZZ4VXWIZJVS  B00005OTZQ       554527960
# 88558          US     34643434  R1LNQR1JD2NKN7  B00005OTZQ       554527960
# 88559          US     51273949  R3RBOY97X8379Y  B00005OTZQ       554527960
# 88560          US     35427145  R1FYGTQEVATD3F  B00005OTZQ       554527960
# 88561          US     36762042  R1C08NPF5FF3JX  B00005OTZQ       554527960
# 88562          US     37368262  R2Y5CQEWBI145K  B00005OTZQ       554527960
# 88563          US     52711734   RWYG4S02ONH29  B00005OTZQ       554527960
# 88564          US     37962550   RGXDLC57AAO4W  B00005OTZQ       554527960
# 88565          US     38978459  R2CDRVDUKB5Z9P  B00005OTZQ       554527960
# 88566          US     51697602   R1DVLTZFXXOX9  B00005OTZQ       554527960
# 88567          US     50891675  R1GHKKZMHAHQC1  B00005OTZQ       554527960
# 88568          US     38528439  R227G6T5B26DVC  B00005OTZQ       554527960
# 88569          US     47099634   R44WS2RSQQ0HR  B00005OTZQ       554527960
#
#                                            product_title    product_category  \
# 0                                   BlackVue DR600GW-PMP  Mobile_Electronics
# 1      GENSSI GSM / GPS Two Way Smart Phone Car Alarm...  Mobile_Electronics
# 2                        iXCC Multi pack Lightning cable  Mobile_Electronics
# 3      abcGoodefg® FBI Covert Acoustic Tube Earpiece ...  Mobile_Electronics
# 4      Generic Car Dashboard Video Camera Vehicle Vid...  Mobile_Electronics
# 5      Aweek® Air Acoustic Earpiece Headset for Baofe...  Mobile_Electronics
# 6      Sentey LS-4460 B-Trek S8 Bluetooth Portable St...  Mobile_Electronics
# 7      iPad Car Headrest Mount Holder for iPad 2/ iPa...  Mobile_Electronics
# 8      ANWING Waterproof Wireless Bluetooth Speaker O...  Mobile_Electronics
# 9      Jensen MCR-100 Cassette Player/Recorder 1 Touc...  Mobile_Electronics
# 10     Bluetooth Speakers, SoundPal Cube F1 5 Watt Bl...  Mobile_Electronics
# 11     15Pcs DC 5V 85dB 2 Pins Industrial Active Elec...  Mobile_Electronics
# 12                                        Sentey Ls 4162  Mobile_Electronics
# 13     IcePACK 8 Can Insulated Cooler Speaker System ...  Mobile_Electronics
# 14     DTK® AMI MDI MMI Adapter 8-PIN Lightning Cable...  Mobile_Electronics
# 15     INPA K+CAN K+DCAN Car Diagnostic tool Cable OB...  Mobile_Electronics
# 16     Magicfly Wireless RF Item Locator Key Finder 1...  Mobile_Electronics
# 17     Humminbird XNT 9 28 T Transom Mount Single/Dua...  Mobile_Electronics
# 18     Bluetooth Speakers, SoundPal Cube F1 5 Watt Bl...  Mobile_Electronics
# 19     Foxnovo 3.7V 380mAh 25C Rechargeable Lipo Batt...  Mobile_Electronics
# 20     AUSDOM AD170 Car DVR Dashboard Camcorder + G-S...  Mobile_Electronics
# 21     Astatic (302-10005) D104M6B Amplified Ceramic ...  Mobile_Electronics
# 22     AODE® 2x A Pair 42mm 3W Super Bright White Car...  Mobile_Electronics
# 23                      1 - Mini Bluetooth Speaker, Blue  Mobile_Electronics
# 24     (2) Skar Audio VD-10 D2 500 Watt RMS Dual 2 Oh...  Mobile_Electronics
# 25     Fm Transmitter, Keedox Car Radio Transmitter C...  Mobile_Electronics
# 26     BaoFeng M-1 Commercial Holster for UV-82 : Cus...  Mobile_Electronics
# 27     Supersonic SC-807 Bluetooth CD/MP3/Cassette Pl...  Mobile_Electronics
# 28     Garmin nüvi 65LM 6-Inch GPS Navigators System ...  Mobile_Electronics
# 29     Bluetooth Speakers, SoundPal Cube F1 5 Watt Bl...  Mobile_Electronics
# ...                                                  ...                 ...
# 88540               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88541  Sony CD Walkman Portable Compact Disc Player D...  Mobile_Electronics
# 88542  Coby Personal CD/MP3 Player with AM/FM Digital...  Mobile_Electronics
# 88543               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88544               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88545  Sony D-EJ1000 CD Walkman with Charging Stand -...  Mobile_Electronics
# 88546  Sony CD Walkman Portable Compact Disc Player D...  Mobile_Electronics
# 88547               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88548               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88549               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88550               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88551               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88552               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88553         SYS TECHNOLOGY 1006 Portable CD MP3 Player  Mobile_Electronics
# 88554               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88555               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88556               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88557               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88558               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88559               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88560               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88561               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88562               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88563               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88564               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88565               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88566               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88567               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88568               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
# 88569               Royal SE 2800 Hand-Held Spot Cleaner  Mobile_Electronics
#
#       star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0               5            0.0          0.0    N                 Y
# 1               5            0.0          1.0    N                 Y
# 2               5            0.0          0.0    N                 Y
# 3               4            0.0          0.0    N                 Y
# 4               2            0.0          0.0    N                 Y
# 5               3            0.0          1.0    N                 Y
# 6               3            0.0          1.0    N                 Y
# 7               5            0.0          0.0    N                 Y
# 8               4            0.0          2.0    N                 Y
# 9               5          164.0        168.0    N                 Y
# 10              5            2.0          2.0    N                 Y
# 11              3            0.0          1.0    N                 Y
# 12              5            0.0          0.0    N                 Y
# 13              1            1.0          1.0    N                 Y
# 14              2            1.0          3.0    N                 Y
# 15              5            2.0          2.0    N                 Y
# 16              2            0.0          0.0    N                 N
# 17              5            1.0          1.0    N                 Y
# 18              4            2.0          2.0    N                 Y
# 19              5            0.0          0.0    N                 Y
# 20              5            0.0          1.0    N                 N
# 21              2            0.0          0.0    N                 Y
# 22              5            0.0          0.0    N                 Y
# 23              5            0.0          0.0    N                 N
# 24              5            1.0          1.0    N                 N
# 25              5            0.0          0.0    N                 Y
# 26              4            0.0          0.0    N                 Y
# 27              1            0.0          0.0    N                 N
# 28              5            0.0          0.0    N                 Y
# 29              5            2.0          2.0    N                 Y
# ...           ...            ...          ...  ...               ...
# 88540           3            0.0          0.0    N                 N
# 88541           5            1.0          1.0    N                 N
# 88542           1            4.0          5.0    N                 N
# 88543           1            0.0          0.0    N                 N
# 88544           2            4.0          4.0    N                 N
# 88545           5            6.0          7.0    N                 N
# 88546           5            4.0          5.0    N                 N
# 88547           4            9.0          9.0    N                 N
# 88548           1            4.0          4.0    N                 N
# 88549           3            3.0          3.0    N                 N
# 88550           1            0.0          0.0    N                 N
# 88551           5            5.0          5.0    N                 Y
# 88552           3            2.0          2.0    N                 N
# 88553           4            0.0          1.0    N                 N
# 88554           5            3.0          3.0    N                 N
# 88555           1            1.0          2.0    N                 N
# 88556           1            1.0          1.0    N                 N
# 88557           1            0.0          0.0    N                 N
# 88558           1            0.0          0.0    N                 N
# 88559           5           41.0         45.0    N                 N
# 88560           5            0.0          1.0    N                 N
# 88561           5            0.0          0.0    N                 N
# 88562           2           48.0         57.0    N                 N
# 88563           5           85.0         95.0    N                 N
# 88564           3            5.0          6.0    N                 N
# 88565           5           23.0         27.0    N                 N
# 88566           5           10.0         11.0    N                 N
# 88567           5           13.0         13.0    N                 N
# 88568           5           58.0         61.0    N                 N
# 88569           4           37.0         38.0    N                 N
#
#                                          review_headline  \
# 0                                            Very Happy!
# 1                                              five star
# 2                                           great cables
# 3      Work very well but couldn't get used to not he...
# 4                             Cameras has battery issues
# 5      It appears to be good, but I'm still waiting f...
# 6                              Didn't love the first one
# 7                                             Five Stars
# 8                                             Four Stars
# 9                                     I LOVE my recorder
# 10                                            Five Stars
# 11     More of a beeper than a buzzer - good part, ba...
# 12                                            Five Stars
# 13                                              One Star
# 14                                             Two Stars
# 15                                            Five Stars
# 16                            Battery Cover Poor Quality
# 17                                          Works great.
# 18                   A Lot of Sound In a Little Package!
# 19                                            Five Stars
# 20                                  I like it so much !!
# 21                                             Two Stars
# 22                                                 Great
# 23                                       Awesome speaker
# 24     i love the sound of skar and in the right box ...
# 25                                           *ss kicker!
# 26                                            Four Stars
# 27                         Skip it.  Buy something else!
# 28                     great price and I like the larger
# 29                                             Rock it!!
# ...                                                  ...
# 88540                           Dirt Devil spot scrubber
# 88541                                        Good Player
# 88542                                          Don't Buy
# 88543                                  Cheap but useless
# 88544              Good scrubber but terrible sucker....
# 88545                                            Err:508
# 88546          very good player that is value for money.
# 88547    Great for spots on floor carpet, not much else.
# 88548                                 very disappointing
# 88549                 Cleans well but not very well made
# 88550  Dont waste your money - pay the extra 10-20 fo...
# 88551                           Love it, great with cats
# 88552                                     great for cars
# 88553                                              Neato
# 88554     It works great with understandable limitations
# 88555                                  Very Dissatisfied
# 88556                                  Very Dissatisfied
# 88557                       Don't waste your money......
# 88558                       Don't waste your money......
# 88559                      A Dream Spot-Cleaning Machine
# 88560                          Kids, kids and more KIDS!
# 88561                                           FABULOUS
# 88562                                  Very Disappointed
# 88563                                           A wonder
# 88564                                        It was Okay
# 88565                              The Cat Barf is Gone!
# 88566                                    Well worth [it]
# 88567                                Its a Time saver!!!
# 88568                                        Got Stains?
# 88569  no smell has to mean it is getting the job don...
#
#                                              review_body review_date  \
# 0      As advertised. Everything works perfectly, I'm...  2015-08-31
# 1                                             it's great  2015-08-31
# 2      These work great and fit my life proof case fo...  2015-08-31
# 3      Work very well but couldn't get used to not he...  2015-08-31
# 4      Be careful with these products, I have bought ...  2015-08-31
# 5      It appears to be good, but I'm still waiting f...  2015-08-31
# 6      First one arrived as a brick.  Wouldn't work, ...  2015-08-31
# 7                              Worked great for vacation  2015-08-31
# 8      this is a very good item, it provide me the so...  2015-08-31
# 9      I LOVE my recorder. Bought it obviously becaus...  2015-08-31
# 10     Great sound great battery beach, work, park, a...  2015-08-31
# 11     If what you want is a continuous tone piezo - ...  2015-08-31
# 12                                               Love it  2015-08-31
# 13                                                 Sucks  2015-08-31
# 14                                u need to plug in both  2015-08-31
# 15     Worked with MHD Flasher for Android.  Used to ...  2015-08-31
# 16     Just arrived,  read instructions and attacked ...  2015-08-31
# 17     I bought this unit as a replacement for my por...  2015-08-31
# 18     I am giving the speakers a test drive as I wri...  2015-08-31
# 19                   Met my application needs very well.  2015-08-31
# 20     This dash cam gives me life. I am an african a...  2015-08-31
# 21                                Scratchy when keyed up  2015-08-31
# 22                                                 Great  2015-08-31
# 23     This was a gift from a friend a year ago and I...  2015-08-31
# 24     i love the sound of skar and in the right box ...  2015-08-31
# 25     Can't go out with it!!!! best gadget for music...  2015-08-31
# 26                             Was everything I expected  2015-08-31
# 27     I was excited to get this product because it l...  2015-08-31
# 28     Outstanding, great price and I like the larger...  2015-08-31
# 29     Nice little unit with great sound.  Built well...  2015-08-31
# ...                                                  ...         ...
# 88540  I have bought this brand before but this littl...  2003-01-03
# 88541  This is one of the best players I've ever had....  2002-12-30
# 88542  The radio is weak; doesn't pull in any normall...  2002-12-25
# 88543  I have bought many Dirt devil product before, ...  2002-12-24
# 88544  The unit is heavy, but nothing too unmanageabl...  2002-12-21
# 88545                                            Err:508  2002-12-20
# 88546  If you looking for an excellent basic player,s...  2002-12-18
# 88547  I bought this product thinking I would use it ...  2002-12-04
# 88548  I thought this would be good for getting out p...  2002-11-17
# 88549  This is very convenient for small spills, vomi...  2002-11-08
# 88550  The only thing this does is suck up liquid thr...  2002-11-03
# 88551  I have this product, use it frequently for cat...  2002-10-27
# 88552  I bought this for small spills & stains and fi...  2002-10-27
# 88553  I do not own and have never tried this idem.  ...  2002-10-23
# 88554  I ordered a Hoover through Amazon and the thin...  2002-10-06
# 88555  I purchased this product because of the satisf...  2002-10-03
# 88556  I purchased this product because of the reputa...  2002-10-03
# 88557  This machine has broken down on me 4 times dur...  2002-09-21
# 88558  I received this as a gift, and have had it ser...  2002-09-21
# 88559  This little spot-scrubber is one hard-working ...  2002-09-08
# 88560  This works great! I have one child who happens...  2002-08-27
# 88561  Works wonders!! Wish I had gotten one sooner a...  2002-08-26
# 88562  I purchased this product based on the reviews ...  2002-08-04
# 88563  Since I have two dogs in a small apartment (in...  2002-06-26
# 88564  I bought the spot scrubber because of all the ...  2002-06-04
# 88565  I've been looking for a while for the \\"purr\...  2002-04-03
# 88566  We live in an apartment with hardwood floors a...  2002-03-05
# 88567  I received this for a birthday present and Its...  2002-02-19
# 88568  I got the Dirt Devil Spot Scrubber for a gift ...  2002-01-06
# 88569  I purchased this about three weeks ago along w...  2001-12-22
#
#             IP Address
# 0       211.200.63.206
# 1        192.17.224.99
# 2          198.9.2.161
# 3        203.46.177.63
# 4      201.159.197.149
# 5       216.93.144.222
# 6       220.211.145.12
# 7        192.183.31.50
# 8       199.113.191.75
# 9       194.248.209.55
# 10       200.15.158.71
# 11       210.7.161.187
# 12     222.246.203.118
# 13      203.223.230.36
# 14     201.133.224.124
# 15      207.63.106.149
# 16     195.170.237.156
# 17       197.65.159.98
# 18     194.159.180.151
# 19      203.108.58.114
# 20     197.197.195.129
# 21      208.63.206.145
# 22      204.164.47.148
# 23     199.171.203.187
# 24       198.60.217.93
# 25     202.109.211.138
# 26      205.82.197.198
# 27       201.83.33.224
# 28       219.254.82.42
# 29      204.33.170.171
# ...                ...
# 88540              NaN
# 88541              NaN
# 88542              NaN
# 88543              NaN
# 88544              NaN
# 88545              NaN
# 88546              NaN
# 88547              NaN
# 88548              NaN
# 88549              NaN
# 88550              NaN
# 88551              NaN
# 88552              NaN
# 88553              NaN
# 88554              NaN
# 88555              NaN
# 88556              NaN
# 88557              NaN
# 88558              NaN
# 88559              NaN
# 88560              NaN
# 88561              NaN
# 88562              NaN
# 88563              NaN
# 88564              NaN
# 88565              NaN
# 88566              NaN
# 88567              NaN
# 88568              NaN
# 88569              NaN
#
# [88570 rows x 16 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import nltk
import re
from nltk.corpus import stopwords 
import collections
from nltk.corpus import wordnet

# %%
dataset.set_index("review_id",inplace=True)

# %%
# Latent symantic analysis
# it will analyse all reviews and determine all reviews belong to the same concept
def LSA(text):
    #text is list of reviews of same product
    
    
    # Created TF-IDF Model
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(text)
    
    # Created SVD(Singular Value Decomposition)
    lsa = TruncatedSVD(n_components = 1,n_iter = 100)
    lsa.fit(X)
    
    terms = vectorizer.get_feature_names()
    concept_words={}

    for j,comp in enumerate(lsa.components_):
        componentTerms = zip(terms,comp)
        sortedTerms = sorted(componentTerms,key=lambda x:x[1],reverse=True)
        sortedTerms = sortedTerms[:10]
        concept_words[str(j)] = sortedTerms
     
    sentence_scores = []
    for key in concept_words.keys():
        for sentence in text:
            words = nltk.word_tokenize(sentence)
            scores = 0
            for word in words:
                for word_with_scores in concept_words[key]:
                    if word == word_with_scores[0]:
                        scores += word_with_scores[1]
            sentence_scores.append(scores)
    return sentence_scores

# %%
product_df = dataset.groupby("product_id")
#grouping dataset by product_id

unique_products = dataset["product_id"].unique()
#stores list of all product id

no_products = len(unique_products.tolist())
#no. of products

remove_reviews = []
#store review_id that are fake 
    
for i in range(no_products):
    #iterate through all product reviews 
    
    df = product_df.get_group(unique_products[i])
    #dataframe of a single product
    
    unique_reviews = df.index.tolist()
    #list of review_id of reviews of same product
    
    no_reviews = len(unique_reviews)   
    #no. of reviews of same product
    
    count = no_reviews 
    #count is no. of reviews that can be analysed
    
    reviews = []
    #list of review texts
    
    review_id = []
    #list of review texts
    
    for j in range(no_reviews):
        #iterate through all reviews
        
        text = str(df.loc[unique_reviews[j]]["review_body"])
        # text of a review 
        
        #cleaning the text
        text = re.sub(r"\W"," ",text)             
        text = re.sub(r"\d"," ",text)             
        text = re.sub(r"\s+[a-z]\s+"," ",text)    
        text = re.sub(r"^[a-z]\s+"," ",text)    
        text = re.sub(r"\s+[a-z]$"," ",text)    
        text = re.sub(r"\s+"," ",text)
        
        words = nltk.word_tokenize(text)
        #text into word list
        
        if(len(words)==1):
        #if only one word in text review
            
            if(len(text) <=1 or not wordnet.synsets(text) ):
            #if word is having only one character or invalid english word
                
                remove_reviews.append(unique_reviews[j])
                #append this review as fake
                
                count-=1
                #review left to be analysed will be decrease by 1
                
                continue
                #check for next review
                '''
            elif(len(words[0])<=1):
                remove_reviews.append(unique_reviews[j])
                count-=1
                continue
                '''
        elif(len(words)==0):
        #if no words
            
            remove_reviews.append(unique_reviews[j])
            #append this review as fake
            
            count-=1
            #review left to be analysed will be decrease by 1
            
            continue
            #check for next review
        
        review_id.append(unique_reviews[j])
        #valid: append review_id to review_id list for analysis
        
        reviews.append(text)
        #valid: append review_body to reviews list for analysis
        
    ###########################################################################################
    if(count<=0):
        #if no reviews left to analyse 

        continue
        #check for next
        
    if(count==1): 
        #if only one review is left to analyse
        
        #check concept between product title and the review
        
        text = [text,str(df.loc[review_id[0]]["product_title"])] 
        #add product_title and review to the list 
        
        sentence_scores = LSA(text) 
        #call LSA method to get the score
        
        if(sentence_scores[0]==0): 
        #if review score is 0, then it's fake
            remove_reviews.append(review_id[0])
        continue
    
    #list of scores of reviews of same product
    sentence_scores = LSA(reviews)
            
    for j in range(len(sentence_scores)):
        #iterating through all the scores
        
        if(sentence_scores[j]==0.00):
            # if score is 0, it's fake
            remove_reviews.append(review_id[j])
